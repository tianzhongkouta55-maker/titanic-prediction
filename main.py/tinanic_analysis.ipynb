# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 使うデータを選び、文字を数字に変換する（機械は数字しか読めないため）
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1}) # 女性を0、男性を1に変換.

# 特徴量（ヒントとなるデータ）とラベル（正解）に分ける
X = df[['Sex', 'Pclass']] # 性別と客室ランクを使う
y = df['Survived']        # 生存したかどうか

# 3. データを「学習用」と「テスト用」に分ける
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)#stratiify=yを追加すると正答率が下がるため今回は追加していない．

# 4. モデル（AIの脳）を作って学習させる
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# 5. 予測して、正解率を出す
predictions = model.predict(X_test)
print(f"正解率: {accuracy_score(y_test, predictions) * 100:.2f}%")
# Out:
# 正解率: 78.77%

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 使うデータを選び、文字を数字に変換する（機械は数字しか読めないため）
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1}) # 女性を0、男性を1に変換.

# データがない場所に、全乗客の年齢の真ん中の値を代入
df['Age'] = df['Age'].fillna(df['Age'].median())

# 特徴量（ヒントとなるデータ）とラベル（正解）に分ける
X = df[['Sex', 'Pclass', 'Age']] # 性別と客室ランク,年齢を使う
y = df['Survived']        # 生存したかどうか

# 3. データを「学習用」と「テスト用」に分ける
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)#stratiify=yを追加すると正答率が下がるため今回は追加していない．

# 4. モデル（AIの脳）を作って学習させる
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# 5. 予測して、正解率を出す
predictions = model.predict(X_test)
print(f"正解率: {accuracy_score(y_test, predictions) * 100:.2f}%")
# Out:
# 正解率: 81.56%

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 使うデータを選び、文字を数字に変換する（機械は数字しか読めないため）
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1}) # 女性を0、男性を1に変換.

# データがない場所に、全乗客の年齢の真ん中の値を代入
df['Age'] = df['Age'].fillna(df['Age'].median())

# 【新しく追加】運賃の欠損値を平均値で埋める
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# 特徴量（ヒントとなるデータ）とラベル（正解）に分ける
X = df[['Sex', 'Pclass', 'Age', 'Fare']] # 性別と客室ランク,年齢，料金を使う
y = df['Survived']        # 生存したかどうか

# 3. データを「学習用」と「テスト用」に分ける
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)#stratiify=yを追加すると正答率が下がるため今回は追加していない．

# 4. モデル（AIの脳）を作って学習させる
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# 5. 予測して、正解率を出す
predictions = model.predict(X_test)
print(f"正解率: {accuracy_score(y_test, predictions) * 100:.2f}%")
# Out:
# 正解率: 80.45%

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 使うデータを選び、文字を数字に変換する（機械は数字しか読めないため）
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1}) # 女性を0、男性を1に変換.

# データがない場所に、全乗客の年齢の真ん中の値を代入
df['Age'] = df['Age'].fillna(df['Age'].median())

# 【新しく追加】運賃の欠損値を平均値で埋める
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# 特徴量（ヒントとなるデータ）とラベル（正解）に分ける
X = df[['Sex', 'Pclass', 'Age', 'Fare', 'SibSp']] # 性別と客室ランク,年齢，料金，兄弟姉妹の数を使う
y = df['Survived']        # 生存したかどうか

# 3. データを「学習用」と「テスト用」に分ける
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)#stratiify=yを追加すると正答率が下がるため今回は追加していない．

# 4. モデル（AIの脳）を作って学習させる
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# 5. 予測して、正解率を出す
predictions = model.predict(X_test)
print(f"正解率: {accuracy_score(y_test, predictions) * 100:.2f}%")
# Out:
# 正解率: 76.54%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 前処理：文字の数値化と欠損値の補完
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1})
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Fare'] = df['Fare'].fillna(df['Fare'].median())

# 特徴量（すべての数値データ）とラベルを選択
X = df[['Sex', 'Pclass', 'Age', 'Fare', 'SibSp', 'Parch']]
y = df['Survived']

# 3. データの分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 4. モデル作成：あえて制限なし（過学習の状態を作る）
model = DecisionTreeClassifier(random_state=0)
model.fit(X_train, y_train)

# 5. 正解率の算出：訓練データとテストデータの差を確認
train_acc = model.score(X_train, y_train) * 100
test_acc = model.score(X_test, y_test) * 100

print(f"訓練データ正解率: {train_acc:.2f}%") # 100%に近いほど「丸暗記」している
print(f"テストデータ正解率: {test_acc:.2f}%") # 訓練データとの差が大きいほど「過学習」
print("-" * 30)

# 6. 特徴量の重要度：どのデータが判断に寄与したか
importances = model.feature_importances_
for name, imp in zip(X.columns, importances):
    print(f"{name}: {imp:.4f}")

# 重要度の可視化
plt.figure(figsize=(8, 4))
plt.barh(X.columns, importances)
plt.title("Feature Importance")
plt.show()
# Out:
# 訓練データ正解率: 98.17%
# テストデータ正解率: 79.33%
# ------------------------------
# Sex: 0.3080
# Pclass: 0.0882
# Age: 0.2393
# Fare: 0.2580
# SibSp: 0.0843
# Parch: 0.0222

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 前処理：文字の数値化と欠損値の補完
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1})
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Fare'] = df['Fare'].fillna(df['Fare'].median())

# 特徴量（すべての数値データ）とラベルを選択
X = df[['Sex', 'Pclass', 'Age', 'Fare', 'SibSp', 'Parch']]
y = df['Survived']

# 3. データの分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 4. 木の深さを「3」に制限してみる（＝細かいことは無視させる）
model = DecisionTreeClassifier(max_depth=3, random_state=0)
model.fit(X_train, y_train)

# 5. 正解率の算出：訓練データとテストデータの差を確認
train_acc = model.score(X_train, y_train) * 100
test_acc = model.score(X_test, y_test) * 100

print(f"訓練データ正解率: {train_acc:.2f}%") # 100%に近いほど「丸暗記」している
print(f"テストデータ正解率: {test_acc:.2f}%") # 訓練データとの差が大きいほど「過学習」
print("-" * 30)

# 6. 特徴量の重要度：どのデータが判断に寄与したか
importances = model.feature_importances_
for name, imp in zip(X.columns, importances):
    print(f"{name}: {imp:.4f}")

# 重要度の可視化
plt.figure(figsize=(8, 4))
plt.barh(X.columns, importances)
plt.title("Feature Importance")
plt.show()
# Out:
# 訓練データ正解率: 83.43%
# テストデータ正解率: 82.12%
# ------------------------------
# Sex: 0.6219
# Pclass: 0.1764
# Age: 0.0707
# Fare: 0.0554
# SibSp: 0.0755
# Parch: 0.0000

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. データの読み込み
df = pd.read_csv('C:\\Users\\User\\Downloads\\titanic-prediction\\data\\train.csv')

# 2. 前処理：文字の数値化と欠損値の補完
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1})
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Fare'] = df['Fare'].fillna(df['Fare'].median())

# 新しい特徴量「FamilySize」を作成（自分＋兄弟配偶者＋親子）
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# 特徴量（すべての数値データ）とラベルを選択
X = df[['Sex', 'Pclass', 'Age', 'Fare', 'FamilySize']]
y = df['Survived']

# 3. データの分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 4. 木の深さを「3」に制限してみる（＝細かいことは無視させる）
model = DecisionTreeClassifier(max_depth=3, random_state=0)
model.fit(X_train, y_train)

# 5. 正解率の算出：訓練データとテストデータの差を確認
train_acc = model.score(X_train, y_train) * 100
test_acc = model.score(X_test, y_test) * 100

print(f"訓練データ正解率: {train_acc:.2f}%") # 100%に近いほど「丸暗記」している
print(f"テストデータ正解率: {test_acc:.2f}%") # 訓練データとの差が大きいほど「過学習」
print("-" * 30)

# 6. 特徴量の重要度：どのデータが判断に寄与したか
importances = model.feature_importances_
for name, imp in zip(X.columns, importances):
    print(f"{name}: {imp:.4f}")

# 重要度の可視化
plt.figure(figsize=(8, 4))
plt.barh(X.columns, importances)
plt.title("Feature Importance")
plt.show()
# Out:
# 訓練データ正解率: 83.43%
# テストデータ正解率: 82.12%
# ------------------------------
# Sex: 0.6219
# Pclass: 0.1764
# Age: 0.0707
# Fare: 0.0554
# FamilySize: 0.0755
